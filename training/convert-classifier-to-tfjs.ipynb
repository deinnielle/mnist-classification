# %%
from google.colab import drive
drive.mount('./mount')

# %%
# !pip install tensorflowjs

# %%
cd mount/My Drive/Colab Notebooks/mnist-classification/

# %%
# !tensorflowjs_converter --input_format keras --output_format tfjs_layers_model mnist-classifier-100.h5 ./tfjs-classifier-100
